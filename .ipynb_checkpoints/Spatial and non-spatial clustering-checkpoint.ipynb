# %%
import numpy as np
import pandas as pd
import geopandas as gpd

from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.preprocessing import minmax_scale

from pysal.region.maxp import Maxp
from pysal.weights import Rook

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# dataset can be created with https://github.com/knaaptime/tstracts
store = pd.HDFStore('data/la_msa_data.h5')
attrs = store.study_data
shp = gpd.GeoDataFrame(store.study_tracts) # need to reinitialize as Geodataframe

# %%
attrs.head()
# Out:
#             geoid    year          pop   pct_lths  pct_bachelor_or_greater  \
# 3696  06037101110  1980.0   587.090269  61.274509                11.507936
# 3697  06037101122  1980.0  6371.203086  61.266336                11.526932
# 3698  06037101210  1980.0  2362.739722  68.875969                 9.689922
# 3699  06037101220  1980.0  2503.260114  68.875970                 9.689922
# 3700  06037101300  1980.0  3829.761102  57.142858                21.107545
#
#       pct_white  pct_black  pct_hispanic  pct_asian  pct_minority  \
# 3696  85.296995   0.614955     10.496157   2.040531     14.703005
# 3697  85.299761   0.614342     10.493172   2.042991     14.700239
# 3698  79.305383   0.184957     16.789971   1.746815     20.694617
# 3699  79.305386   0.184957     16.789972   1.746815     20.694614
# 3700  86.795366   0.283140      8.880309   3.371943     13.204634
#
#               ...            pct_poverty  median_home_value  \
# 3696          ...               7.239033      227403.569836
# 3697          ...               7.234324      227454.095720
# 3698          ...              17.788966      178960.366848
# 3699          ...              17.788966      178960.359979
# 3700          ...               4.736980      251282.671384
#
#       pct_owner_occupied  median_contract_rent  vacancy_rate  \
# 3696           75.739403            709.660018      4.975313
# 3697           75.759869            709.827868      4.969038
# 3698           29.279279            630.200006      6.285178
# 3699           29.279279            630.200006      6.285178
# 3700           86.818846            876.800038      1.451379
#
#       median_household_income  pct_foreign_born  pct_single_mother  \
# 3696             59844.338027          8.972746           7.089152
# 3697             59862.053031          8.976141           7.084510
# 3698             37535.261123         11.652281          19.719473
# 3699             37535.260904         11.652282          19.719472
# 3700             69346.659726         10.810811           4.792043
#
#       housing_units  pct_new_housing_units
# 3696     216.045944               0.645651
# 3697    2344.410583               0.645923
# 3698    1035.216064               0.566604
# 3699    1096.783936               0.566604
# 3700    1358.406860               0.798258
#
# [5 rows x 21 columns]

# %% [markdown]
# `attrs` contains several important tract-level demographic variables from the LTDB database (constructed from https://github.com/knaaptime/tstracts). Currently the data are a timeseries in long-form, so each tract is represented in the dataset 5 times: once each for for 1980, 1990, 2000, 2010, and 2015. Ignoring the temporal dimension for now, we'll use only the 2015 data for a subset of the attributes: race, income, education, and housing price

# %%
# subset the data to 2015, keep a handful of variables, and drop missing observations

attrs = attrs[attrs.year == 2015]
attrs = attrs[['geoid', 'year', 'pct_bachelor_or_greater', 'pct_white',
           'pct_black', 'pct_hispanic', 'pct_asian', 'pct_minority',
           'median_household_income', 'median_home_value']]
attrs = attrs.dropna()

# %%
# keep the tract FIPS as the identifier, drop the useless 'year' variable, and scale the data w/ min-max

attrs.set_index('geoid', inplace=True)
attrs.drop('year', axis=1, inplace=True)
attrs = attrs.transform(minmax_scale)

# %%
shp = shp[ shp.GEOID.isin(attrs.index)]
W = Queen.from_dataframe(shp, idVariable="GEOID")
# Out:
# /Users/knaaptime/anaconda/lib/python3.6/site-packages/pysal/weights/weights.py:189: UserWarning: There are 3 disconnected observations
#   warnings.warn("There are %d disconnected observations" % ni)
# /Users/knaaptime/anaconda/lib/python3.6/site-packages/pysal/weights/weights.py:190: UserWarning: Island ids: 06059063006, 06059062900, 06037620201
#   warnings.warn("Island ids: %s" % ', '.join(str(island) for island in self.islands))

# %%
# maybe a way to drop islands in pysal, but manually here
shp = shp[ -shp.GEOID.isin(['06059063006', '06059062900', '06037620201'])]
W = Queen.from_dataframe(shp, idVariable="GEOID")
W.transform = 'b' # maxp requires binary weights

# %%
# drop islands from the attributes too
attrs = attrs.drop(['06059063006', '06059062900', '06037620201'])

# %%
# fit non-spatial clusters

kmeans = KMeans(n_clusters=10).fit(attrs)
hierarchical = AgglomerativeClustering(n_clusters=10).fit(attrs)

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,20))

ax1.set_aspect('equal')
ax1.axis('off')
ax1.set_title("Hierarchical Clusters")

ax2.set_aspect('equal')
ax2.axis('off')
ax2.set_title("K-Means Clusters")


shp.merge(attrs.assign(cluster = hierarchical.labels_), left_on='GEOID', right_index=True).plot(column="cluster", cmap="tab20", categorical=True, ax=ax1)
shp.merge(attrs.assign(cluster = kmeans.labels_), left_on='GEOID', right_index=True).plot(column="cluster", cmap='tab20', categorical=True, ax=ax2)

# %%
ward = AgglomerativeClustering(n_clusters=10, linkage='ward',
                               connectivity=W.full()[0]).fit(attrs)
# Out:
# /Users/knaaptime/anaconda/lib/python3.6/site-packages/sklearn/cluster/hierarchical.py:193: UserWarning: the number of connected components of the connectivity matrix is 3 > 1. Completing it to avoid stopping the tree early.
#   affinity='euclidean')

# %%
maxp_clusters = Maxp(W, attrs, floor = 10, floor_variable = np.ones((2786, 1)), initial = 6000)
# Out:
# No initial solution found

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,20))

ax1.set_aspect('equal')
ax1.axis('off')
ax1.set_title("Hierarchical Clusters")

ax2.set_aspect('equal')
ax2.axis('off')
ax2.set_title("Constrained Hierarchical Clusters")


shp.merge(attrs.assign(cluster = hierarchical.labels_), left_on='GEOID', right_index=True).plot(column="cluster", categorical=True, ax=ax1, cmap='Paired')
shp.merge(attrs.assign(cluster = ward.labels_), left_on='GEOID', right_index=True).plot(column="cluster", categorical=True, legend=True, cmap='Paired', linewidth=0, ax=ax2)

# %% [markdown]
# Two issues here:
#
# 1. Maxp gives no result; tried with queen and rook, maybe try distance-based?
#
# 2. Results from spatially constrained agglomerative clustering are a little weird. Tried varying K, contiguity, and W-transforms, no change in results. Maybe adding connectivity matric imposes some kind of soft constraint? (like [here](https://arxiv.org/abs/1707.03897) but with no control over $\alpha$?
